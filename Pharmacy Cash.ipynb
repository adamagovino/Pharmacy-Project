# %% [markdown]
# # Creating a Baseline Dictionary of Medication Pricing for Pharmacy Software

# %% [markdown]
# In our pharmacy, we had an issue where we were charging customers (who didn't have insurance) different prices for the same medication.  Unfortunately our existing pharmacy software was lacking in this area.  This is obviously bad practice and I wanted to find a way to, at the end of each month, compare the prices for that month to a dictionary of baseline pricing to see if any of the pricing for that month was off by +/- 5% of previous pricing.  If a prescription was flagged, it would allow us to go back into our system and adjust the pricing accordingly.

# %%
# Reading in all of the cash (out of pocket) pricing from 8 months of data.  

import numpy as np
import pandas as pd
cash = pd.read_csv("/Users/atrain31/Desktop/Pharm Data/cash.csv")
cash["Price Per Unit"] = ""

# %%
cash = cash[cash['Qty']!=0]

# %%
# I created a "Price Per Unit" category in order to determine the price per tablet/capsule/ml/gram of a particular prescription.  This would make a prescription of 60 tablets easy to compare to a script of 30 tablets for the same medication. 

cash["Cost"] = cash["Cost"].astype(float)
cash["Ins Clean"] = cash["Ins Paid"].str.replace(",","")
cash["Ins Clean"] = cash["Ins Clean"].astype(float)
cash["Qty"] = cash["Qty"].astype(float)
cash["Price Per Unit"] = cash["Ins Clean"]/cash["Qty"]
cash = cash[cash["Qty"]!=0]
del cash['Patient Name']

# %%
cash.sort_values('Drug Name')
# Out:
#          Rx Number      Date     Qty                     Drug Name  \
# 12871  0905-438 00  08/21/19   40.00                 BAND AIDS KPP
# 8156   0887-383 02  05/29/19  678.00                      A+D OINT
# 7959   0888-589 02  05/24/19  113.00                      A+D OINT
# 1012   0894-622 00  01/21/19  113.00                      A+D OINT
# 3605   0888-589 01  03/08/19  113.00                      A+D OINT
# 7704   0900-838 00  05/20/19   30.00                   ACIDOPHILUS
# 11208  0903-908 00  07/20/19   30.00     ACIDOPHILUS  PROBIOTIC 1B
# 12202  0904-771 00  08/08/19   28.00          ACIDOPHILUS CHEWABLE
# 9322   0900-882 01  06/17/19   30.00       ACIDOPHILUS XS 3BILLION
# 11265  0900-882 02  07/22/19   30.00       ACIDOPHILUS XS 3BILLION
# 4107   0889-407 05  03/18/19   30.00       ACIDOPHILUS XS 3BILLION
# 618    0889-407 03  01/14/19   30.00       ACIDOPHILUS XS 3BILLION
# 1772   0889-407 04  02/04/19   30.00       ACIDOPHILUS XS 3BILLION
# 5834   0889-407 06  04/17/19   30.00       ACIDOPHILUS XS 3BILLION
# 12684  0900-882 03  08/17/19   30.00       ACIDOPHILUS XS 3BILLION
# 7780   0900-882 00  05/21/19   30.00       ACIDOPHILUS XS 3BILLION
# 7909   0896-866 03  05/24/19   30.00   ACIDOPHILUS/PROBIOTIC SNDWN
# 11075  0896-866 05  07/18/19   30.00   ACIDOPHILUS/PROBIOTIC SNDWN
# 3427   0896-866 00  03/05/19   30.00   ACIDOPHILUS/PROBIOTIC SNDWN
# 4824   0896-866 01  03/29/19   30.00   ACIDOPHILUS/PROBIOTIC SNDWN
# 9561   0896-866 04  06/21/19   30.00   ACIDOPHILUS/PROBIOTIC SNDWN
# 1652   0888-632 05  02/01/19   30.00   ACIDOPHILUS/PROBIOTIC SNDWN
# 6343   0896-866 02  04/26/19   30.00   ACIDOPHILUS/PROBIOTIC SNDWN
# 175    0888-632 04  01/04/19   30.00   ACIDOPHILUS/PROBIOTIC SNDWN
# 402    0894-035 00  01/09/19  532.00            ACT FLUORIDE RINSE
# 4055   0894-035 02  03/17/19  532.00            ACT FLUORIDE RINSE
# 9813   0899-598 02  06/26/19  532.00            ACT FLUORIDE RINSE
# 12726  0899-598 03  08/19/19  532.00            ACT FLUORIDE RINSE
# 2020   0895-565 00  02/08/19  532.00            ACT FLUORIDE RINSE
# 8846   0899-598 01  06/10/19  532.00            ACT FLUORIDE RINSE
# ...            ...       ...     ...                           ...
# 2115   0894-522 01  02/11/19   28.35          ZINC OXIDE OINT (GH)
# 8228   0890-352 03  05/30/19   28.35          ZINC OXIDE OINT (GH)
# 4006   0890-352 02  03/15/19   28.35          ZINC OXIDE OINT (GH)
# 6794   0894-522 05  05/06/19   28.35          ZINC OXIDE OINT (GH)
# 2532   0894-522 02  02/18/19   28.35          ZINC OXIDE OINT (GH)
# 2267   0895-845 00  02/13/19   56.70          ZINC OXIDE OINT (GH)
# 2269   0895-848 00  02/13/19   56.70          ZINC OXIDE OINT (GH)
# 11189  0894-522 06  07/20/19   28.35          ZINC OXIDE OINT (GH)
# 6699   0898-582 01  05/04/19   28.35          ZINC OXIDE OINT (GH)
# 889    0894-522 00  01/18/19   28.35          ZINC OXIDE OINT (GH)
# 12924  0890-352 04  08/22/19   28.35          ZINC OXIDE OINT (GH)
# 1594   0890-352 01  01/30/19   28.35          ZINC OXIDE OINT (GH)
# 9622   0898-592 05  06/22/19   60.00           ZINC OXIDE OINTMENT
# 7849   0898-592 03  05/22/19   60.00           ZINC OXIDE OINTMENT
# 6853   0898-592 02  05/07/19   60.00           ZINC OXIDE OINTMENT
# 6097   0898-592 01  04/22/19   60.00           ZINC OXIDE OINTMENT
# 5171   0898-592 00  04/05/19   60.00           ZINC OXIDE OINTMENT
# 8644   0898-592 04  06/06/19   60.00           ZINC OXIDE OINTMENT
# 6674   0874-859 06  05/03/19   57.00  ZINC OXIDE PLUS A&D OINTMENT
# 890    0894-523 00  01/18/19   30.00             ZINC SULFATE 50MG
# 4291   0894-523 02  03/20/19   30.00             ZINC SULFATE 50MG
# 2719   0894-523 01  02/20/19   30.00             ZINC SULFATE 50MG
# 9520   0901-222 01  06/20/19   30.00             ZINC SULFATE 50MG
# 10864  0901-222 02  07/15/19   30.00             ZINC SULFATE 50MG
# 6360   0894-523 03  04/26/19   30.00             ZINC SULFATE 50MG
# 12360  0904-381 00  08/12/19   30.00             ZINC SULFATE 50MG
# 8096   0901-222 00  05/28/19   30.00             ZINC SULFATE 50MG
# 1642   0888-870 01  01/31/19   30.00          ZIPRASIDONE 20MG CAP
# 3291   0888-870 02  03/04/19   30.00          ZIPRASIDONE 20MG CAP
# 6881   0900-148 00  05/07/19    1.00            ZOLPIDEM 10MG TABS
#
#               Patient Address          Doctor Name Ins Paid   Cost  \
# 12871              W 180TH ST                   MD     3.98   1.50
# 8156      2563 BAINBRIDGE AVE                   MD    41.94  25.68
# 7959         1175 FINDLAY,14D     ROBERSON,FERN NP     6.99   4.28
# 1012          3817 BAILEY AVE                   MD     6.99   4.28
# 3605         1175 FINDLAY,14D     ROBERSON,FERN NP     6.99   4.28
# 7704     1175 FINDLAY AVE 14H       XHOXHI,EVGJENI       12   0.01
# 11208           2518 DAVIDSON       NICHOLS,ANDREA        3   3.00
# 12202         3005 CRUGER AVE       BERGIN,GAIL NP     2.95   2.52
# 9322      1175 FINDLAY AVE 3P     ROBERSON,FERN NP      3.3   2.08
# 11265     1175 FINDLAY AVE 3P     ROBERSON,FERN NP      3.3   2.08
# 4107      1175 FINDLAY AVE 3P     ROBERSON,FERN NP      3.3   2.08
# 618       1175 FINDLAY AVE 3P     ROBERSON,FERN NP      3.3   2.08
# 1772      1175 FINDLAY AVE 3P     ROBERSON,FERN NP      3.3   2.08
# 5834      1175 FINDLAY AVE 3P     ROBERSON,FERN NP      3.3   2.08
# 12684     1175 FINDLAY AVE 3P     ROBERSON,FERN NP      3.3   2.08
# 7780      1175 FINDLAY AVE 3P     ROBERSON,FERN NP      3.3   2.08
# 7909   1815 WHITE PLAINS ROAD      LEAR,LORETTA NP     4.95   2.50
# 11075  1815 WHITE PLAINS ROAD      LEAR,LORETTA NP     4.95   2.50
# 3427   1815 WHITE PLAINS ROAD      LEAR,LORETTA NP     4.95   2.50
# 4824   1815 WHITE PLAINS ROAD      LEAR,LORETTA NP     4.95   2.50
# 9561   1815 WHITE PLAINS ROAD      LEAR,LORETTA NP     4.95   2.50
# 1652   1815 WHITE PLAINS ROAD      LEAR,LORETTA NP     4.95   2.50
# 6343   1815 WHITE PLAINS ROAD      LEAR,LORETTA NP     4.95   2.50
# 175    1815 WHITE PLAINS ROAD      LEAR,LORETTA NP     4.95   2.50
# 402          384 AUDUBON AVE.       ALAM,FARAH DDS     4.95   3.00
# 4055         384 AUDUBON AVE.       ALAM,FARAH DDS     4.95   3.00
# 9813         384 AUDUBON AVE.             KRAUSS,S     4.95   3.00
# 12726        384 AUDUBON AVE.             KRAUSS,S     4.95   3.00
# 2020          3817 BAILEY AVE       KLEIN,VICKI PA     4.95   3.00
# 8846         384 AUDUBON AVE.             KRAUSS,S     4.95   3.00
# ...                       ...                  ...      ...    ...
# 2115        2053 GRAND AVENUE     ROBERSON,FERN NP     2.49   2.93
# 8228           107 PAYSON AVE  ELMORE,SHERLETTE NP     2.49   2.93
# 4006           107 PAYSON AVE  ELMORE,SHERLETTE NP     2.49   2.93
# 6794        2053 GRAND AVENUE     ROBERSON,FERN NP     2.49   2.93
# 2532        2053 GRAND AVENUE     ROBERSON,FERN NP     2.49   2.93
# 2267          3005 CRUGER AVE       BERGIN,GAIL NP     16.2   5.86
# 2269         3005 CRUGER AVE.       BERGIN,GAIL NP     16.2   5.86
# 11189       2053 GRAND AVENUE     ROBERSON,FERN NP     2.49   2.93
# 6699    1972 BENEDICT AVE. GH         KANAVY,HOLLY     2.49   2.93
# 889         2053 GRAND AVENUE     ROBERSON,FERN NP     2.49   2.93
# 12924          107 PAYSON AVE  ELMORE,SHERLETTE NP     2.49   2.93
# 1594           107 PAYSON AVE  ELMORE,SHERLETTE NP     1.99   2.93
# 9622         3005 CRUGER AVE.       BERGIN,GAIL NP     3.98   2.99
# 7849         3005 CRUGER AVE.       BERGIN,GAIL NP     3.98   2.99
# 6853         3005 CRUGER AVE.       BERGIN,GAIL NP     3.98   2.99
# 6097         3005 CRUGER AVE.       BERGIN,GAIL NP     3.98   2.99
# 5171         3005 CRUGER AVE.       BERGIN,GAIL NP     3.98   2.99
# 8644         3005 CRUGER AVE.       BERGIN,GAIL NP     3.98   2.99
# 6674       400 W 43RD ST. 2-H  ELMORE,SHERLETTE NP     6.93   4.15
# 890         2053 GRAND AVENUE     ROBERSON,FERN NP     2.67   1.33
# 4291        2053 GRAND AVENUE     ROBERSON,FERN NP     2.67   1.33
# 2719        2053 GRAND AVENUE     ROBERSON,FERN NP     2.67   1.33
# 9520        2053 GRAND AVENUE     ROBERSON,FERN NP     2.67   1.33
# 10864       2053 GRAND AVENUE     ROBERSON,FERN NP     2.67   1.33
# 6360        2053 GRAND AVENUE     ROBERSON,FERN NP     2.67   1.33
# 12360       2053 GRAND AVENUE     ROBERSON,FERN NP     2.67   1.33
# 8096        2053 GRAND AVENUE     ROBERSON,FERN NP     2.67   1.33
# 1642    1154 ROSEDALE AVE. #1      SIEGEL,ALICE JO    49.95   9.98
# 3291    1154 ROSEDALE AVE. #1      SIEGEL,ALICE JO    49.95   9.98
# 6881     3050 LACONIA AVE. GH          NEY,GERSHON        4   0.02
#
#        Price Per Unit  Ins Clean
# 12871        0.099500       3.98
# 8156         0.061858      41.94
# 7959         0.061858       6.99
# 1012         0.061858       6.99
# 3605         0.061858       6.99
# 7704         0.400000      12.00
# 11208        0.100000       3.00
# 12202        0.105357       2.95
# 9322         0.110000       3.30
# 11265        0.110000       3.30
# 4107         0.110000       3.30
# 618          0.110000       3.30
# 1772         0.110000       3.30
# 5834         0.110000       3.30
# 12684        0.110000       3.30
# 7780         0.110000       3.30
# 7909         0.165000       4.95
# 11075        0.165000       4.95
# 3427         0.165000       4.95
# 4824         0.165000       4.95
# 9561         0.165000       4.95
# 1652         0.165000       4.95
# 6343         0.165000       4.95
# 175          0.165000       4.95
# 402          0.009305       4.95
# 4055         0.009305       4.95
# 9813         0.009305       4.95
# 12726        0.009305       4.95
# 2020         0.009305       4.95
# 8846         0.009305       4.95
# ...               ...        ...
# 2115         0.087831       2.49
# 8228         0.087831       2.49
# 4006         0.087831       2.49
# 6794         0.087831       2.49
# 2532         0.087831       2.49
# 2267         0.285714      16.20
# 2269         0.285714      16.20
# 11189        0.087831       2.49
# 6699         0.087831       2.49
# 889          0.087831       2.49
# 12924        0.087831       2.49
# 1594         0.070194       1.99
# 9622         0.066333       3.98
# 7849         0.066333       3.98
# 6853         0.066333       3.98
# 6097         0.066333       3.98
# 5171         0.066333       3.98
# 8644         0.066333       3.98
# 6674         0.121579       6.93
# 890          0.089000       2.67
# 4291         0.089000       2.67
# 2719         0.089000       2.67
# 9520         0.089000       2.67
# 10864        0.089000       2.67
# 6360         0.089000       2.67
# 12360        0.089000       2.67
# 8096         0.089000       2.67
# 1642         1.665000      49.95
# 3291         1.665000      49.95
# 6881         4.000000       4.00
#
# [13223 rows x 10 columns]

# %%
#Sorting the medications, then finding the maximum/minimum amounts paid per unit for a particular drug 

cash_max = cash.groupby(['Drug Name'])["Price Per Unit"].max()
cash_min = cash.groupby(['Drug Name'])["Price Per Unit"].min()

# %%
#Combining the minimum and maximum amounts paid per unit into a single dataframe

cash_new = pd.merge(cash_min,cash_max, how='inner', on ='Drug Name')
cash_new['Difference'] = cash_new['Price Per Unit_x'] - cash_new['Price Per Unit_y']
cash_new.columns = ["Min Price", "Max Price", "Difference"]
cash_new.to_csv("/Users/atrain31/Desktop/cash_newz.csv")

# %%
# Importing the data from August 2019 to compare to the baseline data.  The bottom of the data was noisy, so ended the data at line 1628

aug = pd.read_csv("/Users/atrain31/Desktop/Pharm Data/aug.csv")
aug = aug[:1628]

# %%
aug['Qty'] = pd.to_numeric(aug['Qty'],errors='coerce')
str_drug = aug['Drug Name'].astype('str')

# %%
# For the August data, essentially doing the same thing as the baseline: finding the price per unit to compare. 

aug['Price'] = aug['Ins Paid']/aug['Qty']
aug['Price'] = aug['Price'].round(5)
aug_new = aug[['Rx Number','Drug Name','Ins Paid','Price']].copy()
aug_new.to_csv("/Users/atrain31/Desktop/augg.csv")

# %%
# Offline, I determined the correct pricing for the medicationas that had been priced oddly/differently for the baseline data.  This was a manual process and there was no way to program this. Importing that data here and created the dictionary from which we can now compare any month's data to. 

otc = pd.read_csv("/Users/atrain31/Desktop/Pharm Data/cashbasenew.csv")
otc.columns = ['drug','accurate']
otc_dict = dict(zip(otc.drug, otc.accurate))

# %%
# Added in values to the dictionary that came up in the August report. 

otc_dict[' BAND AIDS KPP']= 0.1
otc_dict['LEVETIRACETAM 500MG TAB*']=0.665
otc_dict['IBUPROFEN SUS 100/5ML']=0.04223
otc_dict['VIT A+D OINT (GH) 113.4']=0.06
otc_dict['PEG 3350 POWDER (OTC) 510']=0.05
otc_dict['BENZOYL PEROX 5% WASH 237*']=0.09
otc_dict['PULLUP,DEP S/M 43616']=34.95
otc_dict['VIT A+D OINT (GH) 454']=0.02
otc_dict['BENZOYL PEROX 5% WASH 142*'] = 0.09
otc_dict['SUNBLOCK SPF60 LOTION'] = 0.023137
otc_dict['PEG 3350 POWDER (OTC) 510'] = 0.03912
otc_dict['VIT A+D OINT (GH) 454'] = 0.032929
otc_dict['BENZOYL PEROX 5% WASH 237*'] = 0.06308
otc_dict['AM LACTATE 12% LOTION'] = 0.06644
otc_dict['FERROUS SULF LIQ (44MG/5ML)'] = 0.01459
otc_dict['POLYCARBOPHIL 500MG (B)'] = 0.12
otc_dict['DOCUSATE SYRUP *50MG/5ML*'] = 0.01689
otc_dict['BISACODYL 5MG (GH)'] = 0.07
otc_dict['SENNA 8.8MG/5ML SYRUP (GH)'] = 0.09301
otc_dict['VIT D-3 DROPS 400U/ML (GH)'] = 0.1198
otc_dict['FREESTYLE LITE STRIPS'] = 1.99
otc_dict['CHLORHEXIDINE 4% **TOPICAL** S'] = 0.04216
otc_dict['PETROLEUM JELLY (GH)'] = 0.022035
otc_dict['PETROLEUM JELLY (GH) 226'] = 0.022035
otc_dict['PETROLEUM JELLY (GH) 113'] = 0.022035
otc_dict['SOD CHLORID 1GRAM TAB (GH)'] = 0.15
otc_dict['SOD CHLORIDE 1GRAM TAB (GH)'] = 0.15
otc_dict['DESITIN CREAM 113'] = 0.061858
otc_dict['DESITIN CREAM 454'] = 0.03953
otc_dict['DESITIN CREAMY 13%'] = 0.086842
otc_dict['ZINC OXIDE'] = 0.0703703
otc_dict['ZINC OXIDE 25% OINT 56.7'] = 0.0703703
otc_dict['ZINC OXIDE 20% OINT 60'] = 0.0665
otc_dict['ZINC OXIDE 25% OINT 28.35'] = 0.0703703
otc_dict['ZINC OXIDE 20% OINT PLUS A&D'] = 0.12157899999999999
otc_dict['FOLIC ACID 1MG TAB*'] = 0.331666
otc_dict['CALCIUM 1250MG/5ML SUSP (GH)'] = 0.0279
otc_dict['APAP 500MG (GH)'] = 0.07

# %%
# Created a formula to compare the August data to the baseline data.  Any price that was off by +/- 5% would get flagged here and put into the "outliers" list. 

outliers = []
for idx in aug_new.index:
    priceper = aug_new.loc[idx, 'Price']
    price = aug_new.loc[idx, 'Ins Paid']
    drug = aug_new.loc[idx, 'Drug Name']
    value = otc_dict[drug]
    rx = aug_new.loc[idx, 'Rx Number']
    perc = priceper/value
    if price > 1 and(perc < 0.95 or perc > 1.05) :
        outliers.append(rx)
outliers.sort()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
